# %% [markdown]
# ## Test CLIP interpret

# %%
import clip
import torch
import torch.nn as nn
from typing import List
from PIL import Image
from captum.attr import IntegratedGradients, visualization

backbone_ckpt = "/home/ksas/Public/model_zoo/clip"
backbone_name = "ViT-B/32"
device = "cuda:1" if torch.cuda.is_available() else "cpu"

backbone, preprocess = clip.load(backbone_name, device=device, download_root=backbone_ckpt)
backbone = backbone.float()\
            .to("cuda")\
            .eval()

# %%
image:torch.Tensor = preprocess(Image.open("data/images/glasses.png")).unsqueeze(0).to(device)
text = clip.tokenize(["African with sunglasses", "Asisan", "European", "Dog"]).to(device)

image_features = backbone.encode_image(image)
text_features = backbone.encode_text(text)

logits_per_image, logits_per_text = backbone(image, text)
print(logits_per_image)
print(logits_per_text)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 image:torch.Tensor = preprocess(Image.open("data/images/glasses.png")).unsqueeze(0).to(device)
#       2 text = clip.tokenize(["African with sunglasses", "Asisan", "European", "Dog"]).to(device)
# ----> 4 image_features = backbone.encode_image(image)
#       5 text_features = backbone.encode_text(text)
#       7 logits_per_image, logits_per_text = backbone(image, text)
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/clip/model.py:342, in CLIP.encode_image(self, image)
#     341 def encode_image(self, image):
# --> 342     return self.visual(image.type(self.dtype))
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/clip/model.py:224, in VisionTransformer.forward(self, x)
#     223 def forward(self, x: torch.Tensor):
# --> 224     x = self.conv1(x)  # shape = [*, width, grid, grid]
#     225     x = x.reshape(x.shape[0], x.shape[1], -1)  # shape = [*, width, grid ** 2]
#     226     x = x.permute(0, 2, 1)  # shape = [*, grid ** 2, width]
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/env_pcbm_base/lib/python3.12/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:1 and cuda:0! (when checking argument for argument weight in method wrapper_CUDA__cudnn_convolution)

# %%
class ClipVisualWithSimilarity(nn.Module):
    def __init__(self, clip_model, comparison_text:List[str]):
        super(ClipVisualWithSimilarity, self).__init__()
        self.clip_model = clip_model
        self.comparison_text = clip.tokenize(comparison_text).to(device)

    def forward(self, image):
        logits_per_image, _ = self.clip_model(image, self.comparison_text)
        return logits_per_image

# %%
clip_sim = ClipVisualWithSimilarity(backbone, ["a man with eyeglasses",
                                               "smile"])
ig = IntegratedGradients(clip_sim)

# 对图像的 Integrated Gradients 计算
attributions = ig.attribute(image, target=0)
_ = visualization.visualize_image_attr(attributions.squeeze().permute((1, 2, 0)).detach().cpu().numpy(), 
                                       image.squeeze().permute((1, 2, 0)).detach().cpu().numpy(), 
                                       "blended_heat_map")

attributions = ig.attribute(image, target=1)
_ = visualization.visualize_image_attr(attributions.squeeze().permute((1, 2, 0)).detach().cpu().numpy(), 
                                       image.squeeze().permute((1, 2, 0)).detach().cpu().numpy(), 
                                       "blended_heat_map")

# %% [markdown]
# ## Manually interpret

# %%
# !cd scripts/CIFAR_10/embedding_training/ && bash _interpret_base.sh "cifar10" "outputs/trains/cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training/adversarial_saliency_guided_training-open_clip:RN50.pth"    "open_clip:RN50"    "layer_grad_cam"    "cat"    "sharp claws"    "--save-100-local --exp-name=visual_cifar10_open_clipRN50_saliency_map_asgt --zip"
# !cd scripts/CIFAR_10/embedding_training/ && bash _interpret_base.sh "cifar10" "outputs/trains/cifar10_open_clip:RN50_saliency_map_topK=5_concept_KL_div/topK=5-open_clip:RN50.pth"    "open_clip:RN50"    "layer_grad_cam"    "cat"    "sharp claws"    "--save-100-local --exp-name=visual_cifar10_open_clipRN50_saliency_map_topK=5_concept_KL_div_topK=5 --zip"
# !cd scripts/CIFAR_10/embedding_training/ && bash _interpret_base.sh "cifar10" "outputs/trains/cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/adversarial_saliency_guided_training-open_clip:RN50.pth"    "open_clip:RN50"    "layer_grad_cam"    "cat"    "sharp claws"    "--save-100-local --exp-name=visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div --zip"
# !cd scripts/CIFAR_10/embedding_training/ && bash _interpret_base.sh "cifar10" "outputs/clip_adversarial_saliency_guided_training_3e-1/adversarial_saliency_guided_training-open_clip:RN50.pth"    "open_clip:RN50"    "layer_grad_cam"    "cat"    "sharp claws"    "--save-100-local --exp-name=visual_cifar10_open_clipRN50_saliency_map_adversarial_saliency_guided_training_3e-1 --zip"
# !cd scripts/CIFAR_10/embedding_training/ && bash _interpret_base.sh "cifar10" "outputs/trains/cifar10_open_clip:RN50_saliency_map_specific_ocnept_debug-test_concept_KL_div/debug-test-open_clip:RN50.pth"    "open_clip:RN50"    "layer_grad_cam"    "cat"    "sharp claws"    "--save-100-local --exp-name=visual_debug_test --zip"
# Out:
# 2024-11-21 20:47:27,766   INFO  {
#     "universal_seed": 24,
#     "backbone_ckpt": "outputs/trains/cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/adversarial_saliency_guided_training-open_clip:RN50.pth",
#     "backbone_name": "open_clip:RN50",
#     "concept_bank": "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl",
#     "pcbm_ckpt": "data/ckpt/CIFAR_10/pcbm_cifar10__clip:RN50__multimodal_concept_clip:RN50_cifar10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt",
#     "explain_method": "layer_grad_cam",
#     "concept_pooling": "max_pooling_class_wise",
#     "concept_target": "sharp claws",
#     "class_target": "cat",
#     "dataset": "cifar10",
#     "device": "cuda",
#     "batch_size": 1,
#     "num_workers": 4,
#     "exp_name": "visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div",
#     "save_100_local": true,
#     "zip": true,
#     "save_path": "./outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div"
# }
# 2024-11-21 20:47:27,766   INFO  universal seed: 24
# Bank path: /home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl. 175 concepts will be used.
# Concept Bank is initialized.
# open_clip:RN50
# 2024-11-21 20:47:30,720   INFO  37
#  10%|███▊                                   | 986/10000 [00:53<08:11, 18.35it/s]
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/ (stored 0%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/exp_log.log (deflated 78%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/ (stored 0%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/ (stored 0%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/825-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/641-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/607-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/224-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/896-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/863-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/878-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/115-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/470-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/916-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/273-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/063-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/957-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/515-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/811-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/688-captum-image.jpg (deflated 64%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/273-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/664-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/279-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/078-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/061-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/558-captum-image.jpg (deflated 53%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/127-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/866-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/245-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/586-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/870-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/106-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/434-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/078-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/599-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/597-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/432-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/558-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/945-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/565-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/690-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/323-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/597-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/277-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/608-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/948-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/367-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/046-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/399-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/739-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/786-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/739-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/320-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/811-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/676-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/911-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/336-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/412-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/277-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/332-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/464-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/676-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/397-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/273-original_image.jpg (deflated 5%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/792-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/515-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/819-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/397-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/669-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/091-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/456-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/688-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/715-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/008-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/271-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/716-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/399-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/599-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/332-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/412-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/356-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/143-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/637-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/948-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/690-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/932-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/068-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/695-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/294-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/456-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/945-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/046-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/008-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/932-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/845-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/950-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/053-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/467-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/671-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/077-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/882-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/599-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/727-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/367-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/008-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/637-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/470-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/256-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/727-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/911-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/898-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/866-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/256-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/412-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/106-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/896-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/256-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/068-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/205-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/878-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/637-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/916-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/063-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/586-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/251-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/845-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/673-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/336-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/320-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/000-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/467-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/091-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/453-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/000-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/790-captum-image.jpg (deflated 64%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/608-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/279-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/863-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/882-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/426-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/916-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/515-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/608-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/664-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/825-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/176-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/418-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/467-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/103-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/418-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/898-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/205-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/790-original_image.jpg (deflated 7%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/786-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/294-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/205-captum-image.jpg (deflated 52%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/878-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/438-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/279-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/760-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/874-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/323-original_image.jpg (deflated 5%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/831-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/664-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/184-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/320-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/573-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/695-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/356-original_image.jpg (deflated 5%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/127-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/434-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/115-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/646-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/950-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/103-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/863-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/676-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/792-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/176-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/077-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/573-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/650-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/418-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/641-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/063-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/646-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/898-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/000-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/077-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/716-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/845-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/251-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/565-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/224-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/957-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/432-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/434-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/607-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/650-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/121-original_image.jpg (deflated 6%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/811-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/829-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/176-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/831-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/825-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/438-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/669-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/127-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/950-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/091-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/464-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/302-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/106-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/870-captum-image.jpg (deflated 53%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/650-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/669-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/688-original_image.jpg (deflated 7%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/251-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/695-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/607-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/831-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/671-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/597-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/187-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/432-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/184-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/882-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/786-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/053-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/121-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/862-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/739-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/862-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/224-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/673-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/932-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/453-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/399-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/143-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/957-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/397-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/115-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/323-captum-image.jpg (deflated 60%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/456-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/438-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/068-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/760-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/948-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/245-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/464-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/061-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/819-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/874-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/061-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/716-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/690-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/103-captum-image.jpg (deflated 55%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/271-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/277-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/187-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/896-captum-image.jpg (deflated 53%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/862-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/302-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/143-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/053-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/121-captum-image.jpg (deflated 62%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/829-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/453-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/866-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/760-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/715-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/870-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/426-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/586-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/565-captum-image.jpg (deflated 57%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/715-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/558-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/426-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/829-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/874-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/470-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/078-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/646-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/336-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/271-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/184-captum-image.jpg (deflated 59%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/356-attn_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/332-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/641-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/245-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/573-original_image.jpg (deflated 4%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/294-original_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/302-captum-image.jpg (deflated 58%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/367-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/792-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/727-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/187-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/671-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/046-captum-image.jpg (deflated 56%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/911-captum-image.jpg (deflated 54%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/790-attn_image.jpg (deflated 3%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/819-captum-image.jpg (deflated 61%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/945-captum-image.jpg (deflated 53%)
# updating: outputs/evals/visual_cifar10_open_clip:RN50_saliency_map_adversarial_saliency_guided_training_concept_KL_div/layer_grad_cam/sharp claws_images/673-captum-image.jpg (deflated 56%)
