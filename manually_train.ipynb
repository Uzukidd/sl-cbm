# %% [markdown]
# ## Preparing dataset

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/"
BACKBONE_NAME = "clip:ViT-B/32"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "/home/ksas/Public/datasets/cifar10_concept_bank"

# !python3 training_tools/learn_concepts_multimodal.py --backbone-name={BACKBONE_NAME} --classes=cifar10 --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --recurse=1

# %% [markdown]
# ## Training PCBM on the CIFAR-10

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:ViT-B_32_cifar10_recurse:1.pkl"
BACKBONE_NAME = "clip:ViT-B/32"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "data/ckpt/CIFAR_10"
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cifar10" --backbone-name={BACKBONE_NAME} --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --lam=2e-4

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "data/ckpt/CIFAR_10"

# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cifar10" --backbone-name="clip:RN50" --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --lam=2e-4
# Out:
# Bank path: /home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl. 175 concepts will be used.
# Concept Bank is initialized.
# clip:RN50
# 0: 0.853
# 1: 0.916
# 2: 0.69
# 3: 0.755
# 4: 0.758
# 5: 0.689
# 6: 0.869
# 7: 0.834
# 8: 0.875
# 9: 0.857
# OrderedDict({'classifier.weight': tensor([[ 0.0000,  0.0000, -0.4944,  ...,  0.0000, -3.9137, -5.8184],
#         [-3.5069,  0.0000,  0.0000,  ...,  2.1151,  0.0000, -2.2884],
#         [-4.8266, -1.3903,  0.0000,  ...,  0.0000,  0.0000, -0.8105],
#         ...,
#         [ 9.8469,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.3583,  0.0000,  0.0000,  ..., -0.6672,  0.0000, 15.8260],
#         [ 1.8119, -1.5526, -2.9094,  ..., -3.1778,  0.0000,  0.0000]],
#        device='cuda:0'), 'classifier.bias': tensor([ -5.1632, -15.2222,  -1.9142,  -1.0234,  -3.1175,  -0.3023,   1.6727,
#          -0.5773,  -1.2454,   4.0483], device='cuda:0')})
# Class : airplane
# 	 1 - propellers: 23.229
# 	 2 - heavier-than-air craft: 20.210
# 	 3 - fuselage: 16.718
# 	 4 - accelerator: 12.769
# 	 5 - landing gear: 10.355
# Class : automobile
# 	 1 - motor vehicle: 19.194
# 	 2 - vehicle type: 14.890
# 	 3 - gear shift: 14.688
# 	 4 - windshield wiper: 14.433
# 	 5 - windshield: 13.494
# Class : bird
# 	 1 - beak: 20.024
# 	 2 - bird's foot: 17.685
# 	 3 - crow's nest: 10.835
# 	 4 - mute: 8.298
# 	 5 - drumstick: 7.744
# Class : cat
# 	 1 - feline: 26.727
# 	 2 - sharp claws: 10.149
# 	 3 - galley: 8.632
# 	 4 - gray: 8.470
# 	 5 - paws: 7.859
# Class : deer
# 	 1 - antler: 21.197
# 	 2 - an antler: 17.622
# 	 3 - propellers: 15.798
# 	 4 - ruminant: 8.330
# 	 5 - lubber's hole: 7.862
# Class : dog
# 	 1 - canine: 18.496
# 	 2 - white: 14.513
# 	 3 - wishbone: 11.022
# 	 4 - been shaved: 7.753
# 	 5 - paws: 6.995
# Class : frog
# 	 1 - amphibian: 26.107
# 	 2 - bulkhead: 18.078
# 	 3 - uropygium: 18.071
# 	 4 - ridge rope: 14.805
# 	 5 - second joint: 11.337
# Class : horse
# 	 1 - horseback: 22.552
# 	 2 - equine: 15.796
# 	 3 - horsemeat: 9.847
# 	 4 - stallion: 8.800
# 	 5 - horse's foot: 8.086
# Class : ship
# 	 1 - seanchor: 23.680
# 	 2 - navigation light: 21.206
# 	 3 - bilge well: 15.826
# 	 4 - porthole: 14.326
# 	 5 - mare: 13.769
# Class : truck
# 	 1 - gear: 12.079
# 	 2 - an engine: 11.495
# 	 3 - drive train: 8.378
# 	 4 - spar: 8.327
# 	 5 - air sac: 7.813
# Model saved to : data/ckpt/CIFAR_10/pcbm_cifar10__clip:RN50__multimodal_concept_clip:RN50_cifar10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt
# {'train_acc': 81.386, 'test_acc': 80.96, 'cls_acc': {'train': {0: 0.8678, 1: 0.9144, 2: 0.7134, 3: 0.7688, 4: 0.7386, 5: 0.6848, 6: 0.863, 7: 0.8292, 8: 0.8876, 9: 0.871}, 'test': {0: 0.853, 1: 0.916, 2: 0.69, 3: 0.755, 4: 0.758, 5: 0.689, 6: 0.869, 7: 0.834, 8: 0.875, 9: 0.857}}}

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "data/ckpt/CIFAR_10"
PCBM_PATH = "data/ckpt/pcbm_cifar10__clip:RN50__multimodal_concept_clip:RN50_cifar10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt"

# !python3 training_tools/train_pcbm_h.py --concept-bank={CONCEPT_BANK} --dataset-path={DATASET_PATH} --dataset="cifar10" --pcbm-path={PCBM_PATH} --out-dir={OUTPUT_DIR} --backbone-ckpt={BACKBONE_CKPT}

# %% [markdown]
# ## Training PCBM on the CUB

# %%
CONCEPT_BANK = "/home/ksas/uzuki_space/adv-cbm/data/concept_bank/CUB/cub_resnet18_cub_0.1_100.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/resnet_cub"
DATASET_PATH = "/home/ksas/Public/datasets/cub_concept_bank"
OUTPUT_DIR = "data/ckpt/CUB"

# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cub" --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --backbone-name="resnet18_cub" --out-dir={OUTPUT_DIR} --lam=2e-4

# %%
CONCEPT_BANK = "/home/ksas/uzuki_space/adv-cbm/data/concept_bank/CUB/cub_resnet18_cub_0.1_100.pkl"
BACKBONE_CKPT = "/home/ksas/uzuki_space/adv-cbm/data/ckpt/CUB/robust_resnet18_cub.pth"
DATASET_PATH = "/home/ksas/Public/datasets/cub_concept_bank"
OUTPUT_DIR = "data/ckpt/CUB"

# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cub" --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --backbone-name="resnet18_cub" --out-dir={OUTPUT_DIR} --lam=2e-4

# %% [markdown]
# ## Training PCBM on the RIVAL10

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/rival10_concept_bank/multimodal_concept_clip:RN50_rival10_recurse:1.pkl"
BACKBONE_NAME = "clip:RN50"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "None"
OUTPUT_DIR = "data/ckpt/RIVAL_10"
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="rival10" --backbone-name={BACKBONE_NAME} --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --lam=2e-4
# Out:
# Bank path: /home/ksas/Public/datasets/rival10_concept_bank/multimodal_concept_clip:RN50_rival10_recurse:1.pkl. 18 concepts will be used.
# Concept Bank is initialized.
# clip:RN50
# 100%|████████████████████████████████| 84392/84392 [00:00<00:00, 3133687.78it/s]
# 100%|████████████████████████████████| 21144/21144 [00:00<00:00, 3481641.17it/s]
# 100%|█████████████████████████████████████████| 330/330 [00:19<00:00, 16.50it/s]
# 100%|███████████████████████████████████████████| 83/83 [00:04<00:00, 17.87it/s]
# 0: 0.8207171314741036
# 1: 0.8277153558052435
# 2: 0.9716446124763705
# 3: 0.9154135338345865
# 4: 0.9172932330827067
# 5: 0.9585687382297552
# 6: 0.8142589118198874
# 7: 0.9490566037735849
# 8: 0.9320754716981132
# 9: 0.9849906191369606
# Class : truck
# 	 1 - wheels: 23.273
# 	 2 - horns: 17.600
# 	 3 - long: 5.077
# 	 4 - rectangular: 2.391
# 	 5 - wings: 0.000
# Class : car
# 	 1 - wheels: 34.597
# 	 2 - wet: 19.288
# 	 3 - metallic: 11.557
# 	 4 - hairy: 4.221
# 	 5 - text: 0.606
# Class : plane
# 	 1 - wings: 52.285
# 	 2 - tail: 13.063
# 	 3 - long-snout: 9.356
# 	 4 - ears: 1.116
# 	 5 - metallic: 0.354
# Class : ship
# 	 1 - tall: 28.482
# 	 2 - text: 20.806
# 	 3 - rectangular: 18.360
# 	 4 - wet: 8.106
# 	 5 - mane: 2.926
# Class : cat
# 	 1 - hairy: 20.897
# 	 2 - floppy-ears: 19.111
# 	 3 - rectangular: 18.320
# 	 4 - mane: 13.869
# 	 5 - colored-eyes: 8.287
# Class : dog
# 	 1 - floppy-ears: 33.600
# 	 2 - long-snout: 29.918
# 	 3 - hairy: 4.605
# 	 4 - ears: 4.581
# 	 5 - wings: 0.000
# Class : equine
# 	 1 - mane: 40.285
# 	 2 - patterned: 6.285
# 	 3 - tall: 5.975
# 	 4 - tail: 4.336
# 	 5 - wings: 0.000
# Class : deer
# 	 1 - horns: 46.901
# 	 2 - ears: 9.923
# 	 3 - long-snout: 5.956
# 	 4 - tall: 2.918
# 	 5 - floppy-ears: 2.158
# Class : frog
# 	 1 - long-snout: 19.818
# 	 2 - colored-eyes: 17.924
# 	 3 - beak: 17.578
# 	 4 - metallic: 16.236
# 	 5 - wet: 11.449
# Class : bird
# 	 1 - beak: 46.614
# 	 2 - wings: 9.944
# 	 3 - tail: 0.000
# 	 4 - colored-eyes: 0.000
# 	 5 - text: 0.000
# Model saved to : data/ckpt/RIVAL_10/pcbm_rival10__clip:RN50__multimodal_concept_clip:RN50_rival10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt
# {'train_acc': 91.87600720447435, 'test_acc': 90.95724555429436, 'cls_acc': {'train': {0: 0.8249627051218299, 1: 0.8654750705550329, 2: 0.9720379146919431, 3: 0.9193015573383672, 4: 0.91564561734213, 5: 0.9693251533742331, 6: 0.8199811498586239, 7: 0.9480151228733459, 8: 0.9670897978373296, 9: 0.9811853245531514}, 'test': {0: 0.8207171314741036, 1: 0.8277153558052435, 2: 0.9716446124763705, 3: 0.9154135338345865, 4: 0.9172932330827067, 5: 0.9585687382297552, 6: 0.8142589118198874, 7: 0.9490566037735849, 8: 0.9320754716981132, 9: 0.9849906191369606}}}

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/rival10_concept_bank/multimodal_concept_clip:RN50_rival10_recurse:1.pkl"
BACKBONE_NAME = "clip:RN50"
BACKBONE_CKPT = "outputs/clip_rival10_asgt/adversarial_saliency_guided_training-open_clip:RN50.pth"
DATASET_PATH = "None"
OUTPUT_DIR = "data/ckpt/RIVAL_10_asgt"
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
# !python3 training_tools/train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="rival10" --backbone-name={BACKBONE_NAME} --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --lam=2e-4
# Out:
# Bank path: /home/ksas/Public/datasets/rival10_concept_bank/multimodal_concept_clip:RN50_rival10_recurse:1.pkl. 18 concepts will be used.
# Concept Bank is initialized.
# clip:RN50
# 100%|████████████████████████████████| 84392/84392 [00:00<00:00, 3219391.92it/s]
# 100%|████████████████████████████████| 21144/21144 [00:00<00:00, 3703050.81it/s]
# 100%|█████████████████████████████████████████| 330/330 [00:20<00:00, 16.03it/s]
# 100%|███████████████████████████████████████████| 83/83 [00:04<00:00, 17.48it/s]
# 0: 0.9023904382470119
# 1: 0.9569288389513109
# 2: 0.9035916824196597
# 3: 0.9699248120300752
# 4: 0.9154135338345865
# 5: 0.839924670433145
# 6: 0.926829268292683
# 7: 0.960377358490566
# 8: 0.9452830188679245
# 9: 0.9380863039399625
# Class : truck
# 	 1 - wheels: 8.050
# 	 2 - wings: 0.928
# 	 3 - tail: 0.000
# 	 4 - horns: 0.000
# 	 5 - long-snout: 0.000
# Class : car
# 	 1 - wet: 18.470
# 	 2 - wheels: 16.408
# 	 3 - metallic: 7.783
# 	 4 - text: 1.480
# 	 5 - floppy-ears: 0.000
# Class : plane
# 	 1 - wings: 41.494
# 	 2 - tail: 9.960
# 	 3 - long-snout: 4.194
# 	 4 - horns: 3.089
# 	 5 - metallic: 0.175
# Class : ship
# 	 1 - tall: 20.792
# 	 2 - rectangular: 19.931
# 	 3 - text: 9.438
# 	 4 - long: 6.877
# 	 5 - wet: 6.153
# Class : cat
# 	 1 - rectangular: 22.654
# 	 2 - hairy: 13.001
# 	 3 - colored-eyes: 12.453
# 	 4 - floppy-ears: 8.348
# 	 5 - patterned: 6.594
# Class : dog
# 	 1 - long-snout: 22.474
# 	 2 - floppy-ears: 20.949
# 	 3 - ears: 8.608
# 	 4 - hairy: 0.000
# 	 5 - text: 0.000
# Class : equine
# 	 1 - mane: 31.921
# 	 2 - hairy: 11.612
# 	 3 - tail: 6.325
# 	 4 - long: 3.669
# 	 5 - tall: 3.567
# Class : deer
# 	 1 - horns: 37.710
# 	 2 - ears: 13.425
# 	 3 - floppy-ears: 5.160
# 	 4 - beak: 0.000
# 	 5 - tail: 0.000
# Class : frog
# 	 1 - long-snout: 28.721
# 	 2 - colored-eyes: 16.703
# 	 3 - beak: 14.438
# 	 4 - metallic: 13.963
# 	 5 - wet: 7.471
# Class : bird
# 	 1 - beak: 36.254
# 	 2 - tall: 1.627
# 	 3 - text: 0.357
# 	 4 - wet: 0.032
# 	 5 - wings: 0.000
# Model saved to : data/ckpt/RIVAL_10_asgt/pcbm_rival10__clip:RN50__multimodal_concept_clip:RN50_rival10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt
# {'train_acc': 99.16579770594369, 'test_acc': 92.6031025349981, 'cls_acc': {'train': {0: 0.989557434112382, 1: 0.9962370649106302, 2: 0.9928909952606635, 3: 0.9976403964134025, 4: 0.9820923656927427, 5: 0.9848985370457763, 6: 0.9896324222431668, 7: 0.9933837429111532, 8: 0.99529854254819, 9: 0.9948259642521167}, 'test': {0: 0.9023904382470119, 1: 0.9569288389513109, 2: 0.9035916824196597, 3: 0.9699248120300752, 4: 0.9154135338345865, 5: 0.839924670433145, 6: 0.926829268292683, 7: 0.960377358490566, 8: 0.9452830188679245, 9: 0.9380863039399625}}}
