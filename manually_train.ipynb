# %% [markdown]
# ## Training PCBM on the CIFAR-10

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "data/ckpt/"

# !python3 train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cifar10" --backbone-name="clip:RN50" --out-dir={OUTPUT_DIR} --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --lam=2e-4

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cifar10_concept_bank/multimodal_concept_clip:RN50_cifar10_recurse:1.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/clip"
DATASET_PATH = "/home/ksas/Public/datasets/cifar10_concept_bank"
OUTPUT_DIR = "data/ckpt/"
PCBM_PATH = "data/ckpt/pcbm_cifar10__clip:RN50__multimodal_concept_clip:RN50_cifar10_recurse:1__lam:0.0002__alpha:0.99__seed:42.ckpt"

# !python3 train_pcbm_h.py --concept-bank={CONCEPT_BANK} --dataset-path={DATASET_PATH} --dataset="cifar10" --pcbm-path={PCBM_PATH} --out-dir={OUTPUT_DIR} --backbone-ckpt={BACKBONE_CKPT}

# %% [markdown]
# ## Training PCBM on the CUB

# %%
CONCEPT_BANK = "/home/ksas/Public/datasets/cub_concept_bank/cub_resnet18_cub_0.1_100.pkl"
BACKBONE_CKPT = "/home/ksas/Public/model_zoo/resnet_cub"
DATASET_PATH = "/home/ksas/Public/datasets/cub_concept_bank"
OUTPUT_DIR = "data/ckpt/CUB"

# !python3 train_pcbm.py --concept-bank={CONCEPT_BANK} --dataset="cub" --dataset-path={DATASET_PATH} --backbone-ckpt={BACKBONE_CKPT} --backbone-name="resnet18_cub" --out-dir={OUTPUT_DIR} --lam=2e-4
